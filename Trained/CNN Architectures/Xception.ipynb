# %% [markdown]
# # **Rice Plant Disease Classification using CNN Transfer Learning**
# ___

# %%
trainpath= 'D:/Final/Splitted Datasets/train'
validpath='D:/Final/Splitted Datasets/val'
testpath='D:/Final/Splitted Datasets/test'

# %%
img_width, img_height = (224,224)

# %%
batch_size = 20

# %% [markdown]
# ## Data Augumentation
# - To balance the dataset and to increase the size of training and testing dataset
# - Regularization technique to minimize overfitting
# - Rescaling the image is Normalizing the image

# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import preprocess_input

# %%
train_data_generator= ImageDataGenerator(
        #rotation_range=350,
        preprocessing_function=preprocess_input 
    )

train_set = train_data_generator.flow_from_directory(
        trainpath,
        target_size=(img_width,img_height),
        batch_size=batch_size,
        class_mode='categorical'
    )

valid_data_generator = ImageDataGenerator(
        preprocessing_function=preprocess_input
    )

valid_set = valid_data_generator.flow_from_directory(
        validpath,
        target_size=(img_width,img_height),
        batch_size=batch_size,
        class_mode='categorical', 
        shuffle=False 
    )

test_data_generator= ImageDataGenerator()

test_set = test_data_generator.flow_from_directory(
        testpath,
        target_size=(img_width,img_height),
        batch_size=batch_size, 
        class_mode='categorical', 
        shuffle=False
    )
# Out:
# Found 8734 images belonging to 11 classes.
# Found 1092 images belonging to 11 classes.
# Found 1091 images belonging to 11 classes.

# %%
# To print number of batches per epoch
print('Number of Batches per epoch train=%d, valid=%d ,test=%d' % (len(train_set), len(valid_set),len(test_set)))
# Out:
# Number of Batches per epoch train=437, valid=55 ,test=55

# %% [markdown]
# ## Transfer Learning

# %%
from tensorflow.keras.applications.xception import Xception

# %%
base_model = Xception(
        input_shape = (img_width, img_height, 3), 
        include_top = False, 
        weights = 'imagenet'
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 2s 0us/step

# %%
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ## Layers

# %%
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import keras

# %%
x = base_model.output
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Flatten()(base_model.output)
x = keras.layers.Dense(1024, activation='relu')(x)

x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(512, activation='relu')(x)

x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(train_set.num_classes, activation='softmax')(x)

for layer in base_model.layers[:-100]:
   layer.trainable = False

model = tf.keras.models.Model(base_model.input, x)

model.compile(
        optimizer = Adam(learning_rate=0.000001), 
        loss = 'categorical_crossentropy', 
        metrics = ['acc']
    )

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten (Flatten)              (None, 100352)       0           ['block14_sepconv2_act[0][0]']
#
#  dense (Dense)                  (None, 1024)         102761472   ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 512)          524800      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 11)           5643        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 124,153,395
# Trainable params: 123,179,931
# Non-trainable params: 973,464
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
saved_model = "D:/Final/Model/Rice_Xception_50epochs.h5"

# %%
# Saving the model according to the conditions  
checkpoint = ModelCheckpoint(
        saved_model, 
        monitor='val_loss', 
        verbose=1, 
        save_best_only=True, 
        mode='auto'
    )

reduce = ReduceLROnPlateau(
        monitor='val_loss', 
        verbose=1, 
        factor=0.1, 
        patience=2, 
        mode='auto'
    )

# %%
epochs = 50

# %%
# Train the model
trained_model = model.fit(
        train_set,
        steps_per_epoch = train_set.samples//train_set.batch_size,
        epochs = epochs,
        validation_data = valid_set,
        validation_steps = valid_set.samples//valid_set.batch_size,
        callbacks=[checkpoint,reduce]
    )
# Out:
# Epoch 1/50
#  18/436 [>.............................] - ETA: 27:32 - loss: 2.6309 - acc: 0.0750
# c:\Users\IT Room202\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:979: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 436/436 [==============================] - ETA: 0s - loss: 2.2468 - acc: 0.2216
# Epoch 1: val_loss improved from inf to 1.65334, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1720s 4s/step - loss: 2.2468 - acc: 0.2216 - val_loss: 1.6533 - val_acc: 0.6204 - lr: 1.0000e-06
# Epoch 2/50
# 436/436 [==============================] - ETA: 0s - loss: 1.7103 - acc: 0.4524
# Epoch 2: val_loss improved from 1.65334 to 1.14945, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1712s 4s/step - loss: 1.7103 - acc: 0.4524 - val_loss: 1.1495 - val_acc: 0.7389 - lr: 1.0000e-06
# Epoch 3/50
# 436/436 [==============================] - ETA: 0s - loss: 1.3406 - acc: 0.5842
# Epoch 3: val_loss improved from 1.14945 to 0.81328, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 1.3406 - acc: 0.5842 - val_loss: 0.8133 - val_acc: 0.7963 - lr: 1.0000e-06
# Epoch 4/50
# 436/436 [==============================] - ETA: 0s - loss: 1.1027 - acc: 0.6566
# Epoch 4: val_loss improved from 0.81328 to 0.64069, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1747s 4s/step - loss: 1.1027 - acc: 0.6566 - val_loss: 0.6407 - val_acc: 0.8194 - lr: 1.0000e-06
# Epoch 5/50
# 436/436 [==============================] - ETA: 0s - loss: 0.9130 - acc: 0.7138
# Epoch 5: val_loss improved from 0.64069 to 0.52239, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1779s 4s/step - loss: 0.9130 - acc: 0.7138 - val_loss: 0.5224 - val_acc: 0.8435 - lr: 1.0000e-06
# Epoch 6/50
# 436/436 [==============================] - ETA: 0s - loss: 0.8032 - acc: 0.7358
# Epoch 6: val_loss improved from 0.52239 to 0.45427, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1721s 4s/step - loss: 0.8032 - acc: 0.7358 - val_loss: 0.4543 - val_acc: 0.8500 - lr: 1.0000e-06
# Epoch 7/50
# 436/436 [==============================] - ETA: 0s - loss: 0.7034 - acc: 0.7703
# Epoch 7: val_loss improved from 0.45427 to 0.39638, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1701s 4s/step - loss: 0.7034 - acc: 0.7703 - val_loss: 0.3964 - val_acc: 0.8620 - lr: 1.0000e-06
# Epoch 8/50
# 436/436 [==============================] - ETA: 0s - loss: 0.6297 - acc: 0.7979
# Epoch 8: val_loss improved from 0.39638 to 0.35862, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1704s 4s/step - loss: 0.6297 - acc: 0.7979 - val_loss: 0.3586 - val_acc: 0.8787 - lr: 1.0000e-06
# Epoch 9/50
# 436/436 [==============================] - ETA: 0s - loss: 0.5758 - acc: 0.8069
# Epoch 9: val_loss improved from 0.35862 to 0.32484, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 0.5758 - acc: 0.8069 - val_loss: 0.3248 - val_acc: 0.8898 - lr: 1.0000e-06
# Epoch 10/50
# 436/436 [==============================] - ETA: 0s - loss: 0.5122 - acc: 0.8343
# Epoch 10: val_loss improved from 0.32484 to 0.29445, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1730s 4s/step - loss: 0.5122 - acc: 0.8343 - val_loss: 0.2944 - val_acc: 0.9046 - lr: 1.0000e-06
# Epoch 11/50
# 436/436 [==============================] - ETA: 0s - loss: 0.4616 - acc: 0.8489
# Epoch 11: val_loss improved from 0.29445 to 0.26930, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1836s 4s/step - loss: 0.4616 - acc: 0.8489 - val_loss: 0.2693 - val_acc: 0.9093 - lr: 1.0000e-06
# Epoch 12/50
# 436/436 [==============================] - ETA: 0s - loss: 0.4178 - acc: 0.8610
# Epoch 12: val_loss improved from 0.26930 to 0.24706, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1778s 4s/step - loss: 0.4178 - acc: 0.8610 - val_loss: 0.2471 - val_acc: 0.9167 - lr: 1.0000e-06
# Epoch 13/50
# 436/436 [==============================] - ETA: 0s - loss: 0.3965 - acc: 0.8675
# Epoch 13: val_loss improved from 0.24706 to 0.23027, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1732s 4s/step - loss: 0.3965 - acc: 0.8675 - val_loss: 0.2303 - val_acc: 0.9231 - lr: 1.0000e-06
# Epoch 14/50
# 436/436 [==============================] - ETA: 0s - loss: 0.3692 - acc: 0.8780
# Epoch 14: val_loss improved from 0.23027 to 0.21859, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1707s 4s/step - loss: 0.3692 - acc: 0.8780 - val_loss: 0.2186 - val_acc: 0.9269 - lr: 1.0000e-06
# Epoch 15/50
# 436/436 [==============================] - ETA: 0s - loss: 0.3407 - acc: 0.8835
# Epoch 15: val_loss improved from 0.21859 to 0.20053, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1716s 4s/step - loss: 0.3407 - acc: 0.8835 - val_loss: 0.2005 - val_acc: 0.9315 - lr: 1.0000e-06
# Epoch 16/50
# 436/436 [==============================] - ETA: 0s - loss: 0.3144 - acc: 0.8968
# Epoch 16: val_loss improved from 0.20053 to 0.19598, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1706s 4s/step - loss: 0.3144 - acc: 0.8968 - val_loss: 0.1960 - val_acc: 0.9287 - lr: 1.0000e-06
# Epoch 17/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2857 - acc: 0.9046
# Epoch 17: val_loss improved from 0.19598 to 0.18484, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1709s 4s/step - loss: 0.2857 - acc: 0.9046 - val_loss: 0.1848 - val_acc: 0.9333 - lr: 1.0000e-06
# Epoch 18/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2692 - acc: 0.9144
# Epoch 18: val_loss improved from 0.18484 to 0.17707, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1711s 4s/step - loss: 0.2692 - acc: 0.9144 - val_loss: 0.1771 - val_acc: 0.9417 - lr: 1.0000e-06
# Epoch 19/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2604 - acc: 0.9153
# Epoch 19: val_loss improved from 0.17707 to 0.16709, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1704s 4s/step - loss: 0.2604 - acc: 0.9153 - val_loss: 0.1671 - val_acc: 0.9398 - lr: 1.0000e-06
# Epoch 20/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2405 - acc: 0.9241
# Epoch 20: val_loss improved from 0.16709 to 0.16142, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1702s 4s/step - loss: 0.2405 - acc: 0.9241 - val_loss: 0.1614 - val_acc: 0.9407 - lr: 1.0000e-06
# Epoch 21/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2263 - acc: 0.9245
# Epoch 21: val_loss improved from 0.16142 to 0.15530, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1710s 4s/step - loss: 0.2263 - acc: 0.9245 - val_loss: 0.1553 - val_acc: 0.9454 - lr: 1.0000e-06
# Epoch 22/50
# 436/436 [==============================] - ETA: 0s - loss: 0.2100 - acc: 0.9322
# Epoch 22: val_loss improved from 0.15530 to 0.15179, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 0.2100 - acc: 0.9322 - val_loss: 0.1518 - val_acc: 0.9454 - lr: 1.0000e-06
# Epoch 23/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1946 - acc: 0.9364
# Epoch 23: val_loss improved from 0.15179 to 0.14630, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 0.1946 - acc: 0.9364 - val_loss: 0.1463 - val_acc: 0.9426 - lr: 1.0000e-06
# Epoch 24/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1847 - acc: 0.9412
# Epoch 24: val_loss improved from 0.14630 to 0.14223, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1697s 4s/step - loss: 0.1847 - acc: 0.9412 - val_loss: 0.1422 - val_acc: 0.9454 - lr: 1.0000e-06
# Epoch 25/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1690 - acc: 0.9468
# Epoch 25: val_loss did not improve from 0.14223
# 436/436 [==============================] - 1688s 4s/step - loss: 0.1690 - acc: 0.9468 - val_loss: 0.1444 - val_acc: 0.9491 - lr: 1.0000e-06
# Epoch 26/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1672 - acc: 0.9445
# Epoch 26: val_loss improved from 0.14223 to 0.13699, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 0.1672 - acc: 0.9445 - val_loss: 0.1370 - val_acc: 0.9509 - lr: 1.0000e-06
# Epoch 27/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1473 - acc: 0.9512
# Epoch 27: val_loss improved from 0.13699 to 0.13521, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1701s 4s/step - loss: 0.1473 - acc: 0.9512 - val_loss: 0.1352 - val_acc: 0.9528 - lr: 1.0000e-06
# Epoch 28/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1357 - acc: 0.9567
# Epoch 28: val_loss improved from 0.13521 to 0.13127, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1700s 4s/step - loss: 0.1357 - acc: 0.9567 - val_loss: 0.1313 - val_acc: 0.9528 - lr: 1.0000e-06
# Epoch 29/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1298 - acc: 0.9586
# Epoch 29: val_loss improved from 0.13127 to 0.13068, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1696s 4s/step - loss: 0.1298 - acc: 0.9586 - val_loss: 0.1307 - val_acc: 0.9546 - lr: 1.0000e-06
# Epoch 30/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1228 - acc: 0.9587
# Epoch 30: val_loss improved from 0.13068 to 0.12781, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1698s 4s/step - loss: 0.1228 - acc: 0.9587 - val_loss: 0.1278 - val_acc: 0.9565 - lr: 1.0000e-06
# Epoch 31/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1181 - acc: 0.9628
# Epoch 31: val_loss improved from 0.12781 to 0.12288, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1692s 4s/step - loss: 0.1181 - acc: 0.9628 - val_loss: 0.1229 - val_acc: 0.9583 - lr: 1.0000e-06
# Epoch 32/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1091 - acc: 0.9665
# Epoch 32: val_loss did not improve from 0.12288
# 436/436 [==============================] - 1682s 4s/step - loss: 0.1091 - acc: 0.9665 - val_loss: 0.1256 - val_acc: 0.9583 - lr: 1.0000e-06
# Epoch 33/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1082 - acc: 0.9675
# Epoch 33: val_loss did not improve from 0.12288
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 436/436 [==============================] - 1681s 4s/step - loss: 0.1082 - acc: 0.9675 - val_loss: 0.1240 - val_acc: 0.9611 - lr: 1.0000e-06
# Epoch 34/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1032 - acc: 0.9665
# Epoch 34: val_loss did not improve from 0.12288
# 436/436 [==============================] - 1682s 4s/step - loss: 0.1032 - acc: 0.9665 - val_loss: 0.1238 - val_acc: 0.9583 - lr: 1.0000e-07
# Epoch 35/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1039 - acc: 0.9694
# Epoch 35: val_loss improved from 0.12288 to 0.12280, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 436/436 [==============================] - 1690s 4s/step - loss: 0.1039 - acc: 0.9694 - val_loss: 0.1228 - val_acc: 0.9639 - lr: 1.0000e-07
# Epoch 36/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1053 - acc: 0.9663
# Epoch 36: val_loss improved from 0.12280 to 0.12271, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1689s 4s/step - loss: 0.1053 - acc: 0.9663 - val_loss: 0.1227 - val_acc: 0.9593 - lr: 1.0000e-08
# Epoch 37/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0987 - acc: 0.9688
# Epoch 37: val_loss did not improve from 0.12271
# 436/436 [==============================] - 1680s 4s/step - loss: 0.0987 - acc: 0.9688 - val_loss: 0.1235 - val_acc: 0.9602 - lr: 1.0000e-08
# Epoch 38/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0985 - acc: 0.9715
# Epoch 38: val_loss did not improve from 0.12271
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 436/436 [==============================] - 1704s 4s/step - loss: 0.0985 - acc: 0.9715 - val_loss: 0.1235 - val_acc: 0.9602 - lr: 1.0000e-08
# Epoch 39/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0973 - acc: 0.9694
# Epoch 39: val_loss improved from 0.12271 to 0.12238, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1696s 4s/step - loss: 0.0973 - acc: 0.9694 - val_loss: 0.1224 - val_acc: 0.9620 - lr: 1.0000e-09
# Epoch 40/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1036 - acc: 0.9658
# Epoch 40: val_loss did not improve from 0.12238
# 436/436 [==============================] - 1687s 4s/step - loss: 0.1036 - acc: 0.9658 - val_loss: 0.1225 - val_acc: 0.9602 - lr: 1.0000e-09
# Epoch 41/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0968 - acc: 0.9702
# Epoch 41: val_loss improved from 0.12238 to 0.12133, saving model to D:/Final/Model\Rice_Xception_50epochs.h5
# 436/436 [==============================] - 1690s 4s/step - loss: 0.0968 - acc: 0.9702 - val_loss: 0.1213 - val_acc: 0.9620 - lr: 1.0000e-09
# Epoch 42/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0986 - acc: 0.9702
# Epoch 42: val_loss did not improve from 0.12133
# 436/436 [==============================] - 1677s 4s/step - loss: 0.0986 - acc: 0.9702 - val_loss: 0.1224 - val_acc: 0.9611 - lr: 1.0000e-09
# Epoch 43/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0953 - acc: 0.9699
# Epoch 43: val_loss did not improve from 0.12133
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# 436/436 [==============================] - 1677s 4s/step - loss: 0.0953 - acc: 0.9699 - val_loss: 0.1230 - val_acc: 0.9593 - lr: 1.0000e-09
# Epoch 44/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0952 - acc: 0.9706
# Epoch 44: val_loss did not improve from 0.12133
# 436/436 [==============================] - 1684s 4s/step - loss: 0.0952 - acc: 0.9706 - val_loss: 0.1222 - val_acc: 0.9620 - lr: 1.0000e-10
# Epoch 45/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0995 - acc: 0.9678
# Epoch 45: val_loss did not improve from 0.12133
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# 436/436 [==============================] - 1680s 4s/step - loss: 0.0995 - acc: 0.9678 - val_loss: 0.1235 - val_acc: 0.9611 - lr: 1.0000e-10
# Epoch 46/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0951 - acc: 0.9714
# Epoch 46: val_loss did not improve from 0.12133
# 436/436 [==============================] - 1681s 4s/step - loss: 0.0951 - acc: 0.9714 - val_loss: 0.1235 - val_acc: 0.9593 - lr: 1.0000e-11
# Epoch 47/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1022 - acc: 0.9659
# Epoch 47: val_loss did not improve from 0.12133
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999092680235e-13.
# 436/436 [==============================] - 1685s 4s/step - loss: 0.1022 - acc: 0.9659 - val_loss: 0.1231 - val_acc: 0.9602 - lr: 1.0000e-11
# Epoch 48/50
# 436/436 [==============================] - ETA: 0s - loss: 0.0980 - acc: 0.9684
# Epoch 48: val_loss did not improve from 0.12133
# 436/436 [==============================] - 1678s 4s/step - loss: 0.0980 - acc: 0.9684 - val_loss: 0.1246 - val_acc: 0.9583 - lr: 1.0000e-12
# Epoch 49/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1016 - acc: 0.9681
# Epoch 49: val_loss did not improve from 0.12133
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.9999988758398e-14.
# 436/436 [==============================] - 1681s 4s/step - loss: 0.1016 - acc: 0.9681 - val_loss: 0.1222 - val_acc: 0.9602 - lr: 1.0000e-12
# Epoch 50/50
# 436/436 [==============================] - ETA: 0s - loss: 0.1049 - acc: 0.9664
# Epoch 50: val_loss did not improve from 0.12133
# 436/436 [==============================] - 1681s 4s/step - loss: 0.1049 - acc: 0.9664 - val_loss: 0.1240 - val_acc: 0.9611 - lr: 1.0000e-13

# %%
model.save("Xception50")
model.save("Xception50.h5")

s = model.to_json()
with open('Xception_model.json', 'w') as f:
    f.write(s)

model.save_weights("Xception50weights")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 41). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Xception50\assets
# INFO:tensorflow:Assets written to: Xception50\assets

# %%
training_accuracy      = trained_model.history['acc'][-1]
training_loss          = trained_model.history['loss'][-1]
validation_accuracy    = trained_model.history['val_acc'][-1]
validation_loss       = trained_model.history['val_loss'][-1]
print("Training Accuracy   :", training_accuracy )
print("Training Loss       :", training_loss)
print("Validation Accuracy :", validation_accuracy)
print("Validation Loss     :", validation_loss)
# Out:
# Training Accuracy   : 0.9663759469985962
# Training Loss       : 0.10487795621156693
# Validation Accuracy : 0.9611111283302307
# Validation Loss     : 0.12400461733341217

# %% [markdown]
# ## Loss and Accuracy Visualization

# %%
import matplotlib.pyplot as plt

# %%
acc = trained_model.history['acc']
val_acc = trained_model.history['val_acc']
loss = trained_model.history['loss']
val_loss = trained_model.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Load Model

# %%
import tensorflow as tf
new_model = tf.keras.models.load_model(saved_model)

# %%
predict = new_model.predict(
        test_set,
        steps=len(test_set),
        verbose=1
    )
# Out:
# 55/55 [==============================] - 62s 1s/step

# %%
predict
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.0297524e-12, 2.0815605e-02, 9.8172465e-22, ..., 1.8831896e-13,
#         3.8333467e-36, 1.0607265e-17],
#        [1.0000000e+00, 4.6849169e-18, 4.0284319e-19, ..., 1.8440468e-09,
#         3.5842118e-38, 7.4132533e-11],
#        ...,
#        [9.9999988e-01, 9.0647994e-08, 0.0000000e+00, ..., 1.9786030e-17,
#         0.0000000e+00, 2.0547066e-33],
#        [9.9943143e-01, 1.3101565e-12, 7.1047054e-16, ..., 1.8128931e-05,
#         2.6486911e-26, 5.6972975e-11],
#        [1.0868385e-03, 3.0661600e-30, 1.9421671e-27, ..., 0.0000000e+00,
#         0.0000000e+00, 4.9570776e-34]], dtype=float32)

# %%
import numpy as np

# %%
rounded_predictions = np.argmax(predict,axis=-1)

# %%
rounded_predictions
# Out:
# array([6, 4, 0, ..., 0, 0, 7], dtype=int64)

# %%
rounded_predictions.shape
# Out:
# (1091,)

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
test_set.class_indices
# Out:
# {'Bacterial_Blight': 0,
#  'Blast': 1,
#  'Brown_Spot': 2,
#  'False_Smut': 3,
#  'Healthy': 4,
#  'Healthy_Flowers': 5,
#  'Hispa': 6,
#  'Leaf_Smut': 7,
#  'Sheath_Blight': 8,
#  'Tungro': 9,
#  'Unhealthy_Flowers': 10}

# %%
test_labels=test_set.classes
test_labels
# Out:
# array([ 0,  0,  0, ..., 10, 10, 10])

# %%
test_labels.shape
# Out:
# (1091,)

# %%
class_list = []
for keys in test_set.class_indices.keys():
    class_list.append(keys)

# %%
cm = confusion_matrix(y_true=test_labels, y_pred=rounded_predictions)
cm
# Out:
# array([[43,  9,  0,  1,  4,  0, 28, 12,  0,  0,  3],
#        [34, 10,  0,  0,  0,  0, 46,  9,  1,  0,  0],
#        [30,  0,  0,  0,  6,  0, 60,  3,  0,  0,  1],
#        [26, 21,  0,  1,  7,  1,  5, 28,  9,  0,  2],
#        [71,  6,  0,  0,  0,  0,  0, 12,  5,  0,  0],
#        [47, 14,  0,  1,  6,  0,  1, 22,  8,  0,  1],
#        [27,  1,  0,  0,  8,  1, 55,  2,  0,  0,  3],
#        [37,  3,  2,  0,  1,  0, 37, 12,  4,  0,  4],
#        [38, 15,  0,  0,  3,  1, 10, 26,  2,  0,  5],
#        [77, 10,  1,  0,  0,  0,  1, 10,  0,  0,  1],
#        [52, 14,  0,  0,  2,  0,  1, 17,  9,  0,  5]], dtype=int64)

# %%
fig,ax=plot_confusion_matrix(conf_mat=cm,figsize=(8,8),show_normed=True, class_names=class_list)
plt.show()

# %%
print('test accuracy: {0:2f}'.format((np.diagonal(cm).sum()/cm.sum().sum()*100)))
# Out:
# test accuracy: 11.732356

# %%
import sklearn.metrics as metrics

# %%
class_list = []
for keys in test_set.class_indices.keys():
    class_list.append(keys)

class_list
# Out:
# ['Bacterial_Blight',
#  'Blast',
#  'Brown_Spot',
#  'False_Smut',
#  'Healthy',
#  'Healthy_Flowers',
#  'Hispa',
#  'Leaf_Smut',
#  'Sheath_Blight',
#  'Tungro',
#  'Unhealthy_Flowers']

# %%
classify_report = metrics.classification_report(
        y_true=test_labels, 
        y_pred=rounded_predictions,
        target_names=class_list
    )

print('classify_report : \n', classify_report)
# Out:
# classify_report :
#                     precision    recall  f1-score   support
#
#  Bacterial_Blight       0.09      0.43      0.15       100
#             Blast       0.10      0.10      0.10       100
#        Brown_Spot       0.00      0.00      0.00       100
#        False_Smut       0.33      0.01      0.02       100
#           Healthy       0.00      0.00      0.00        94
#   Healthy_Flowers       0.00      0.00      0.00       100
#             Hispa       0.23      0.57      0.32        97
#         Leaf_Smut       0.08      0.12      0.09       100
#     Sheath_Blight       0.05      0.02      0.03       100
#            Tungro       0.00      0.00      0.00       100
# Unhealthy_Flowers       0.20      0.05      0.08       100
#
#          accuracy                           0.12      1091
#         macro avg       0.10      0.12      0.07      1091
#      weighted avg       0.10      0.12      0.07      1091
# c:\Users\IT Room202\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\IT Room202\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\IT Room202\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
overall_accuracy = metrics.accuracy_score(
        y_true=test_labels, 
        y_pred=rounded_predictions
    )
acc_for_each_class = metrics.precision_score(
        y_true=test_labels, 
        y_pred=rounded_predictions, 
        average=None
    )
average_accuracy = np.mean(acc_for_each_class)
score = metrics.accuracy_score(
        y_true=test_labels, 
        y_pred=rounded_predictions
    )

print('ac_for_each_class : \n', acc_for_each_class)
print('average_accuracy: {0:2f}'.format(average_accuracy))
print('overall_accuracy: {0:2f}'.format(overall_accuracy))
print('score: {0:f}'.format(score))
# Out:
# ac_for_each_class :
#  [0.08921162 0.09708738 0.         0.33333333 0.         0.
#  0.22540984 0.07843137 0.05263158 0.         0.2       ]
# average_accuracy: 0.097828
# overall_accuracy: 0.117324
# score: 0.117324
# c:\Users\IT Room202\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(test_labels, predict[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(test_labels))]
p_fpr, p_tpr, _ = roc_curve(test_labels, random_probs, pos_label=1)

# %%
# matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='ResNet50')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
# Out:
# C:\Users\IT Room202\AppData\Local\Temp\ipykernel_9084\1087658176.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ROC AUC Score

# %%
from sklearn.metrics import roc_auc_score

# auc scores
# auc_score1 = roc_auc_score(test_labels, predict[:,1])
auc_score1 = roc_auc_score(y_score=predict, y_true=test_labels, multi_class="ovr",average=None)

ind = 0
for score in auc_score1:
    print("%s : %.3f" % (class_list[ind], score))
    ind += 1
# Out:
# Bacterial_Blight : 0.484
# Blast : 0.401
# Brown_Spot : 0.249
# False_Smut : 0.655
# Healthy : 0.462
# Healthy_Flowers : 0.746
# Hispa : 0.656
# Leaf_Smut : 0.416
# Sheath_Blight : 0.594
# Tungro : 0.354
# Unhealthy_Flowers : 0.659

# %% [markdown]
# ___

# %%
import cv2
import numpy as np
image=cv2.imread("D:/Testing/sheathblight (2).jpg")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
img_resized=cv2.resize(image, (img_width, img_height))
image=np.expand_dims(img_resized,axis=0)
print(image.shape)

plt.figure(figsize = (2,2))
plt.imshow(img_resized)
plt.show()
# Out:
# (1, 224, 224, 3)

# %%
prediction = model.predict(image)
print(prediction)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[9.9999809e-01 1.3012699e-10 4.4526997e-20 1.3222534e-14 9.6426434e-15
#   6.2964182e-19 1.6368504e-06 1.3985115e-07 1.6799414e-11 1.6073091e-23
#   8.1760518e-08]]

# %%
class_output = class_list[np.argmax(prediction)]
print(class_output)
# Out:
# Bacterial_Blight

# %%
predicted_acuracy = ("{:.2%}".format(np.array(prediction[0])[np.argmax(prediction)]))
print(predicted_acuracy)
# Out:
# 100.00%

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = class_list
values = list(np.array(np.around(prediction[0] * 100,2)))

x = np.arange(len(labels))  # the label locations
width = 0.80  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x, values, width, label='Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores of Prediction by Classes')
ax.set_xticks(x, labels)
plt.xticks(rotation=65)
ax.legend()

ax.bar_label(rects1, padding=2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ___

# %%
import os
import cv2
import numpy as np
path = "D:/Testing"
for img in os.listdir(path):
    try:
        image = cv2.imread(os.path.join(path, img))
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        img_resized=cv2.resize(image, (img_width, img_height))
        new_image=np.expand_dims(img_resized,axis=0)
        # print(image.shape)

        prediction = new_model.predict(new_image)

        class_output = class_list[np.argmax(prediction)]
        #print(class_output)
        predicted_acuracy = ("{:.2%}".format(np.array(prediction[0])[np.argmax(prediction)]))
        #print(predicted_acuracy)
        
        plt.figure(figsize = (2,2))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        plt.imshow(image)
        plt.title(class_output + "(" + predicted_acuracy + ")")
        plt.show()

    except Exception as e:
        print(e)
    print("----------------------------------------------------------------------------------")
# Out:
# 1/1 [==============================] - 1s 788ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 157ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 143ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 120ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 123ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 124ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 126ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 114ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 118ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 121ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 126ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 114ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 110ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 120ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 118ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 112ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 117ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 118ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 129ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 116ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 116ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 115ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 115ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 125ms/step
# ----------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 119ms/step
# ----------------------------------------------------------------------------------

# %% [markdown]
# ---

# %%
import cv2
import numpy as np

img=cv2.imread("D:/invalid.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_resized=cv2.resize(img, (img_width, img_height))
image=np.expand_dims(img_resized,axis=0)
#print(image.shape)

# prediction = trained_model.model.predict(image)
prediction = new_model.predict(image)
#print(prediction)

class_output = class_list[np.argmax(prediction)]
#print(class_output)

accuracy = np.array(prediction[0])[np.argmax(prediction)]
predicted_acuracy = ("{:.2%}".format(accuracy))
print(predicted_acuracy)

if(accuracy * 100 < 75):
    class_output = "Invalid Image!"
    print(class_output, " try to test another image.")

plt.figure(figsize = (2,2))
plt.imshow(img)
plt.title(class_output + "(" + predicted_acuracy + ")")
plt.show()
# Out:
# 1/1 [==============================] - 0s 121ms/step
# 99.82%
